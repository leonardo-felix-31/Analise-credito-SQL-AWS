# %% [markdown]
# # **Exploração e análise de dados de crédito com SQL**
#
# *Esse notebook faz parte do curso SQL para análise de dados da EBAC.*
#
# ## Os dados:
#
# Os dados representam informações de clientes de um banco e contam com as seguintes colunas:
#
# * idade = idade do cliente
# * sexo = sexo do cliente (F ou M)
# * dependentes = número de dependentes do cliente
# * escolaridade = nível de escolaridade do clientes
# * salario_anual = faixa salarial do cliente
# * tipo_cartao = tipo de cartao do cliente
# * qtd_produtos = quantidade de produtos comprados nos últimos 12 meses
# * iteracoes_12m = quantidade de iterações/transacoes nos ultimos 12 meses
# * meses_inativo_12m = quantidade de meses que o cliente ficou inativo
# * limite_credito = limite de credito do cliente
# * valor_transacoes_12m = valor das transações dos ultimos 12 meses
# * qtd_transacoes_12m  = quantidade de transacoes dos ultimos 12 meses
#
# A tabela foi criada no **AWS Athena** junto com o **S3 Bucket** com uma versão dos dados disponibilizados em: https://github.com/andre-marcos-perez/ebac-course-utils/tree/main/dataset

# %% [markdown]
# ## Objetivo da análise:

# %% [markdown]
# * Visando entender melhor o perfil dos clientes e oferecer serviços personalizados, precisamos responder as seguintes perguntas de negócios:
#     * Como as idades dos clientes estão distribuidas?
#     * Existem mais clientes mulheres ou homens?
#     * Mulheres ou homens gastam mais?
#     * Qual estado civil predomina entre os clientes?
#     * Tipo de cartão mais utilizado em pagamentos?
#     * Qual é o salário anual da maioria dos clientes?
#     * O salário impacta diretamente o limite de crédito?
#
# * !! Utilizaremos o aws athena para realizar as consultas sql, e o google colab para visualização de dados.

# %% [markdown]
# #### Conhecendo os dados:

# %%
# INPUT
Image(filename="C:\\Users\\USER\\OneDrive\\Imagens\\Capturas de tela\\Captura de tela 2025-02-23 155555.png")

# %%
# OUTPUT
Image(filename="C:\\Users\\USER\\OneDrive\\Imagens\\Capturas de tela\\Captura de tela 2025-02-23 155606.png")

# %% [markdown]
# #### Número de clientes registrados na base de dados:

# %%
# INPUT
from IPython.display import Image
Image(filename="C:\\Users\\USER\\OneDrive\\Imagens\\Capturas de tela\\Captura de tela 2025-02-23 155323.png")

# %%
# OUTPUT
Image(filename="C:\\Users\\USER\\OneDrive\\Imagens\\Capturas de tela\\Captura de tela 2025-02-23 155343.png")

# %% [markdown]
# #### Como as idades dos clientes estão distribuídas?

# %%
# INPUT
Image(filename="C:\\Users\\USER\\OneDrive\\Imagens\\Capturas de tela\\Captura de tela 2025-02-23 155358.png")

# %%
# OUTPUT
Image(filename="C:\\Users\\USER\\OneDrive\\Imagens\\Capturas de tela\\Captura de tela 2025-02-23 155408.png")

# %%
# VISUALIZAÇÃO
Image(filename="C:\\Users\\USER\\OneDrive\\Imagens\\Capturas de tela\\Captura de tela 2025-02-23 181731.png")

# %% [markdown]
# #### Existem mais clientes mulheres ou homens?

# %%
# INPUT
Image(filename="C:\\Users\\USER\\OneDrive\\Imagens\\Capturas de tela\\Captura de tela 2025-02-23 155423.png")

# %%
# OUTPUT
Image(filename="C:\\Users\\USER\\OneDrive\\Imagens\\Capturas de tela\\Captura de tela 2025-02-23 155432.png")

# %%
# VISUALIZAÇÃO
Image(filename="C:\\Users\\USER\\OneDrive\\Imagens\\Capturas de tela\\Captura de tela 2025-02-23 182504.png")

# %% [markdown]
# #### Mulheres ou homens gastam mais?

# %%
# INPUT
Image(filename="C:\\Users\\USER\\OneDrive\\Imagens\\Capturas de tela\\Captura de tela 2025-02-23 155716.png")

# %%
# OUTPUT
Image(filename="C:\\Users\\USER\\OneDrive\\Imagens\\Capturas de tela\\Captura de tela 2025-02-23 155727.png")

# %% [markdown]
# #### Qual estado civil predomina entre os clientes?

# %%
# INPUT
Image(filename="C:\\Users\\USER\\OneDrive\\Imagens\\Capturas de tela\\Captura de tela 2025-02-23 155447.png")

# %%
# OUTPUT
Image(filename="C:\\Users\\USER\\OneDrive\\Imagens\\Capturas de tela\\Captura de tela 2025-02-23 155456.png")

# %%
# VISUALIZAÇÃO
Image(filename="C:\\Users\\USER\\OneDrive\\Imagens\\Capturas de tela\\Captura de tela 2025-02-23 183044.png")

# %% [markdown]
# #### Tipo de cartão mais utilizado em pagamentos?

# %%
# iNPUT
Image(filename="C:\\Users\\USER\\OneDrive\\Imagens\\Capturas de tela\\Captura de tela 2025-02-23 155514.png")

# %%
# OUTPUT
Image(filename="C:\\Users\\USER\\OneDrive\\Imagens\\Capturas de tela\\Captura de tela 2025-02-23 155521.png")

# %% [markdown]
# #### Qual é o salário anual da maioria dos clientes?

# %%
# INPUT
Image(filename="C:\\Users\\USER\\OneDrive\\Imagens\\Capturas de tela\\Captura de tela 2025-02-23 155640.png")

# %%
# OUTPUT
Image(filename="C:\\Users\\USER\\OneDrive\\Imagens\\Capturas de tela\\Captura de tela 2025-02-23 155651.png")

# %% [markdown]
# #### O salário impacta diretamente o limite de crédito?

# %%
# INPUT
Image(filename="C:\\Users\\USER\\OneDrive\\Imagens\\Capturas de tela\\Captura de tela 2025-02-23 155740.png")

# %%
# OUTPUT
Image(filename="C:\\Users\\USER\\OneDrive\\Imagens\\Capturas de tela\\Captura de tela 2025-02-23 155803.png")

# %% [markdown]
# # Conclusão

# %% [markdown]
# #### Insigths obtidos(respostas):
#
# * As idades dos clientes variam entre 26 a 73 anos, com a maior parte concentrada em 45 anos.
# * A maior parte dos clientes são homens.
# * As mulheres gastam mais que os homens.
# * A maior parte dos clientes são casados.
# * O cartão blue se destaca como cartão mais utilizado entre os clientes.
# * A maioria dos clientes tem salários abaixo de $40K.
